# %%
import numpy as np
from nilearn import datasets
from nilearn.input_data import NiftiLabelsMasker
from nilearn.image import index_img
import nibabel as nib
from sklearn.cross_decomposition import PLSRegression
from sklearn.cross_decomposition import CCA
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold 

brain_data = datasets.fetch_oasis_vbm(n_subjects=100)
# Out:
# ...
#      |████████████████████████████████| 10.0 MB 13.1 MB/s
# ...
# /usr/local/lib/python3.7/dist-packages/nilearn/datasets/__init__.py:96: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)
# Dataset created in /root/nilearn_data/oasis1
#
# ...
# Downloaded 897277952 of 905208634 bytes (99.1%,    0.3s remaining) ...done. (31 seconds, 0 min)
# Extracting data from /root/nilearn_data/oasis1/adcb228c7b26ed4f4fba93bd32bf8d97/archive_dartel.tgz..... done.
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py:2349: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   output = genfromtxt(fname, **kwargs)

# %%
def plot_each_n_rois(i):
  crad = datasets.fetch_atlas_craddock_2012()
  atlas_nii = index_img(crad['scorr_mean'], i) # this needs to be modified for some tasks
  print('%i regions found in this atlas' % (len(np.unique(atlas_nii.get_data().ravel())) - 1))
  masker = NiftiLabelsMasker(labels_img= atlas_nii, standardize=True)
  input_variables = masker.fit_transform(brain_data.gray_matter_maps)
  output_variable = StandardScaler().fit_transform(brain_data.ext_vars.age[:, None])[:, 0] # gives subject age on standard units after z-scoring

  kf = KFold(n_splits=5)
  pls2_train_accuracy = 0
  cca_train_accuracy = 0
  pcr_train_accuracy = 0

  pls2_test_accuracy = 0
  cca_test_accuracy = 0
  pcr_test_accuracy = 0

  for train_index, test_index in kf.split(output_variable):
    X_train, X_test = input_variables[train_index], input_variables[test_index]
    y_train, y_test = output_variable[train_index], output_variable[test_index]

    pca = PCA(n_components=3).fit(X_train) ### feature engineering on train_split
    pca_train_input = pca.transform(X_train)
    pca_test_input = pca.transform(X_test)

    pls2 = PLSRegression(n_components=2)
    pls2.fit(pca_train_input, y_train)
    pls2_train_accuracy += pls2.score(pca_train_input, y_train)
    pls2_test_accuracy += pls2.score(pca_test_input, y_test)


    cca = CCA(n_components=2)
    cca.fit(pca_train_input, y_train)
    cca_train_accuracy += cca.score(pca_train_input, y_train)
    cca_test_accuracy += cca.score(pca_test_input, y_test)


    pcr = (make_pipeline(StandardScaler(), PCA(n_components=1), LinearRegression()))
    pcr.fit(pca_train_input, y_train)
    pcr_train_accuracy += pcr.score(pca_train_input, y_train)
    pcr_test_accuracy += pcr.score(pca_test_input, y_test)

  return i, pls2_train_accuracy/5, cca_train_accuracy/5, pcr_train_accuracy/5, pls2_test_accuracy/5, cca_test_accuracy/5, pcr_test_accuracy/5

x_list = [] ### n_rois
pls2_y_list_train = [] ### accuracy
cca_y_list_train = []
pcr_y_list_train = []
pls2_y_list_test = [] ### accuracy
cca_y_list_test = []
pcr_y_list_test = []

for i in range(43):
  i, pls2_train_accuracy, cca_train_accuracy, pcr_train_accuracy, pls2_test_accuracy, cca_test_accuracy, pcr_test_accuracy = plot_each_n_rois(i)
  x_list.append(i)
  pls2_y_list_train.append(pls2_train_accuracy)
  cca_y_list_train.append(cca_train_accuracy)
  pcr_y_list_train.append(pcr_train_accuracy)
  pls2_y_list_test.append(pls2_test_accuracy)
  cca_y_list_test.append(cca_test_accuracy)
  pcr_y_list_test.append(pcr_test_accuracy)

plt.xticks(x_list)
plt.plot(x_list,pls2_y_list_train,label='PLS train')
plt.plot(x_list,cca_y_list_train,label='CCA train')
plt.plot(x_list,pcr_y_list_train,label='PCR train')
plt.plot(x_list,pls2_y_list_test,label='PLS test')
plt.plot(x_list,cca_y_list_test,label='CCA test')
plt.plot(x_list,pcr_y_list_test,label='PCR test')

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   after removing the cwd from sys.path.
# 10 regions found in this atlas
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:252: FutureWarning: As of version 0.24, n_components(2) should be in [1, min(n_features, n_samples, n_targets)] = [1, 1]. n_components=1 will be used instead. In version 1.1 (renaming of 0.26), an error will be raised.
#   FutureWarning,
# ...
